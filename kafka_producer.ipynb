# %%
import logging

# Cria um logger com o nome 'jupyter_logger'
logger = logging.getLogger('jupyter_logger')

# Define o nível de log para DEBUG, então todas as mensagens de log serão mostradas
logger.setLevel(logging.DEBUG)

# Cria um manipulador de log que escreve as mensagens de log na saída padrão
handler = logging.StreamHandler()

# Define o nível de log do manipulador para DEBUG
handler.setLevel(logging.DEBUG)

# Cria um formatador de log que adiciona a data e hora à mensagem de log
formatter = logging.Formatter('%(asctime)s - %(name)s - %(levelname)s - %(message)s')

# Adiciona o formatador ao manipulador
handler.setFormatter(formatter)

# Adiciona o manipulador ao logger
logger.addHandler(handler)

# Agora você pode usar o logger para registrar mensagens de log
logger.debug('Esta é uma mensagem de debug')
logger.info('Esta é uma mensagem de info')
logger.warning('Esta é uma mensagem de warning')
logger.error('Esta é uma mensagem de error')
logger.critical('Esta é uma mensagem de critical')
# Out:
# 2024-05-19 18:45:43,541 - jupyter_logger - DEBUG - Esta é uma mensagem de debug
# 2024-05-19 18:45:43,542 - jupyter_logger - INFO - Esta é uma mensagem de info
# 2024-05-19 18:45:43,543 - jupyter_logger - WARNING - Esta é uma mensagem de warning
# 2024-05-19 18:45:43,543 - jupyter_logger - ERROR - Esta é uma mensagem de error
# 2024-05-19 18:45:43,544 - jupyter_logger - CRITICAL - Esta é uma mensagem de critical

# %%
from confluent_kafka import Producer
# topic = "user"

class Kafka_producer:
    def __init__(self,broker = "kafka-broker:9092",group_id = "python"):
        self._broker = broker
        self._group_id = group_id
        self._producer = self._making_the_producer()
        return
    def _making_the_producer(self):
        logger.debug('Configuring code')
        config = {
                'bootstrap.servers': self._broker,
                'group.id': self._group_id,
                'auto.offset.reset': 'latest',
                'enable.auto.commit': 'false',
                'max.poll.interval.ms': '86400000'
            }
        return Producer(config)
    
    def kafka_producer(self,topic, data):

        def _delivery_report(err, msg):
            if err is not None:
                logger.debug('Message delivery failed: {}'.format(err))
            else:
                logger.debug('Message delivered to {} [{}]'.format(msg.topic(), msg.partition()))
        logger.debug('Publishing to topic')
        self._producer.produce(topic, data, callback=_delivery_report)
        self._producer.flush()

# %%
import requests

def get_data_from_endpoint():
    url = "https://random-data-api.com/api/v2/users?size=1"
    response = requests.get(url)
    if response.status_code == 200:
        return response.json()
    else:
        return None

# %%
import json
from time import sleep


producer = Kafka_producer()

while True:
    logger.debug('sending mensage')
    producer.kafka_producer(topic="user", data=json.dumps(get_data_from_endpoint()))
    sleep(10)
# Out:
# 2024-05-19 18:46:34,358 - jupyter_logger - DEBUG - Configuring code
# DEBUG:jupyter_logger:Configuring code
# 2024-05-19 18:46:34,361 - jupyter_logger - DEBUG - sending mensage
# DEBUG:jupyter_logger:sending mensage
# 2024-05-19 18:46:35,164 - jupyter_logger - DEBUG - Publishing to topic
# DEBUG:jupyter_logger:Publishing to topic
# 2024-05-19 18:46:35,368 - jupyter_logger - DEBUG - Message delivered to user [0]
# DEBUG:jupyter_logger:Message delivered to user [0]
# 2024-05-19 18:46:45,381 - jupyter_logger - DEBUG - sending mensage
# DEBUG:jupyter_logger:sending mensage
# 2024-05-19 18:46:45,916 - jupyter_logger - DEBUG - Publishing to topic
# DEBUG:jupyter_logger:Publishing to topic
# 2024-05-19 18:46:45,922 - jupyter_logger - DEBUG - Message delivered to user [0]
# DEBUG:jupyter_logger:Message delivered to user [0]
# 2024-05-19 18:46:55,933 - jupyter_logger - DEBUG - sending mensage
# DEBUG:jupyter_logger:sending mensage
# 2024-05-19 18:46:56,669 - jupyter_logger - DEBUG - Publishing to topic
# DEBUG:jupyter_logger:Publishing to topic
# 2024-05-19 18:46:56,677 - jupyter_logger - DEBUG - Message delivered to user [0]
# DEBUG:jupyter_logger:Message delivered to user [0]
# 2024-05-19 18:47:06,690 - jupyter_logger - DEBUG - sending mensage
# DEBUG:jupyter_logger:sending mensage
# 2024-05-19 18:47:07,216 - jupyter_logger - DEBUG - Publishing to topic
# DEBUG:jupyter_logger:Publishing to topic
# 2024-05-19 18:47:07,219 - jupyter_logger - DEBUG - Message delivered to user [0]
# DEBUG:jupyter_logger:Message delivered to user [0]
# 2024-05-19 18:47:17,230 - jupyter_logger - DEBUG - sending mensage
# DEBUG:jupyter_logger:sending mensage
# 2024-05-19 18:47:17,865 - jupyter_logger - DEBUG - Publishing to topic
# DEBUG:jupyter_logger:Publishing to topic
# 2024-05-19 18:47:17,869 - jupyter_logger - DEBUG - Message delivered to user [0]
# DEBUG:jupyter_logger:Message delivered to user [0]
# 2024-05-19 18:47:27,881 - jupyter_logger - DEBUG - sending mensage
# DEBUG:jupyter_logger:sending mensage
# 2024-05-19 18:47:28,498 - jupyter_logger - DEBUG - Publishing to topic
# DEBUG:jupyter_logger:Publishing to topic
# 2024-05-19 18:47:28,505 - jupyter_logger - DEBUG - Message delivered to user [0]
# DEBUG:jupyter_logger:Message delivered to user [0]
# 2024-05-19 18:47:38,518 - jupyter_logger - DEBUG - sending mensage
# DEBUG:jupyter_logger:sending mensage
# 2024-05-19 18:47:39,089 - jupyter_logger - DEBUG - Publishing to topic
# DEBUG:jupyter_logger:Publishing to topic
# 2024-05-19 18:47:39,092 - jupyter_logger - DEBUG - Message delivered to user [0]
# DEBUG:jupyter_logger:Message delivered to user [0]
# 2024-05-19 18:47:49,101 - jupyter_logger - DEBUG - sending mensage
# DEBUG:jupyter_logger:sending mensage
# 2024-05-19 18:47:49,923 - jupyter_logger - DEBUG - Publishing to topic
# DEBUG:jupyter_logger:Publishing to topic
# 2024-05-19 18:47:49,926 - jupyter_logger - DEBUG - Message delivered to user [0]
# DEBUG:jupyter_logger:Message delivered to user [0]
# 2024-05-19 18:47:59,937 - jupyter_logger - DEBUG - sending mensage
# DEBUG:jupyter_logger:sending mensage
# 2024-05-19 18:48:00,573 - jupyter_logger - DEBUG - Publishing to topic
# DEBUG:jupyter_logger:Publishing to topic
# 2024-05-19 18:48:00,581 - jupyter_logger - DEBUG - Message delivered to user [0]
# DEBUG:jupyter_logger:Message delivered to user [0]
# 2024-05-19 18:48:10,593 - jupyter_logger - DEBUG - sending mensage
# DEBUG:jupyter_logger:sending mensage
# 2024-05-19 18:48:11,216 - jupyter_logger - DEBUG - Publishing to topic
# DEBUG:jupyter_logger:Publishing to topic
# 2024-05-19 18:48:11,219 - jupyter_logger - DEBUG - Message delivered to user [0]
# DEBUG:jupyter_logger:Message delivered to user [0]
# 2024-05-19 18:48:21,230 - jupyter_logger - DEBUG - sending mensage
# DEBUG:jupyter_logger:sending mensage
# 2024-05-19 18:48:21,672 - jupyter_logger - DEBUG - Publishing to topic
# DEBUG:jupyter_logger:Publishing to topic
# 2024-05-19 18